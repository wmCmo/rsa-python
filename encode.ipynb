# %%
def encode(input, pub, n):
    input = input.split(" ")
    output = list()
    for word in input:
        output.append([((ord(char)**pub) % n) for char in word])
    return output

# %%
[[2441828, 626770, 2441828, 1555193, 2212907, 836185, 1672401], [300532, 707801, 2096034, 2441828],[157801, 707801, 2412799, 2651915, 2259336, 1331693, 2441828, 1555193],[2096034, 836185, 2212907],[391959, 2441828, 391959, 641106, 2441828, 1555193],[2096034, 836185, 707801, 2212907, 626770],[391959, 2441828, 836185, 2412799, 794261, 1555193, 2441828],[1672401, 2441828, 2651915, 626770, 794261, 1555193, 2441828],[2259336, 977854, 2412799, 626770, 2441828, 1555193],[1808918, 1672401, 836185, 2212907, 2441828, 626770],[2412799, 626770, 2259336, 2212907, 2441828],[2412799, 1714317, 2441828, 157801]]

# %%
digest = [[2441828, 626770, 2441828, 1555193, 2212907, 836185, 1672401],
          [300532, 707801, 2096034, 2441828],
          [157801, 707801, 2412799, 2651915, 2259336, 1331693, 2441828, 1555193],
          [2096034, 836185, 2212907],
          [391959, 2441828, 391959, 641106, 2441828, 1555193],
          [2096034, 836185, 707801, 2212907, 626770],
          [391959, 2441828, 836185, 2412799, 794261, 1555193, 2441828],
          [1672401, 2441828, 2651915, 626770, 794261, 1555193, 2441828],
          [2259336, 977854, 2412799, 626770, 2441828, 1555193],
          [1808918, 1672401, 836185, 2212907, 2441828, 626770],
          [2412799, 626770, 2259336, 2212907, 2441828],
          [2412799, 1714317, 2441828, 157801]]

# %%
import json

# %%
# Out:
# [[2441828, 626770, 2441828, 1555193, 2212907, 836185, 1672401],
#  [300532, 707801, 2096034, 2441828],
#  [157801, 707801, 2412799, 2651915, 2259336, 1331693, 2441828, 1555193],
#  [2096034, 836185, 2212907],
#  [391959, 2441828, 391959, 641106, 2441828, 1555193],
#  [2096034, 836185, 707801, 2212907, 626770],
#  [391959, 2441828, 836185, 2412799, 794261, 1555193, 2441828],
#  [1672401, 2441828, 2651915, 626770, 794261, 1555193, 2441828],
#  [2259336, 977854, 2412799, 626770, 2441828, 1555193],
#  [1808918, 1672401, 836185, 2212907, 2441828, 626770],
#  [2412799, 626770, 2259336, 2212907, 2441828],
#  [2412799, 1714317, 2441828, 157801]]

# %%
# Out:
# ['2441828',
#  ' 626770',
#  ' 2441828',
#  ' 1555193',
#  ' 2212907',
#  ' 836185',
#  ' 1672401]',
#  ' [300532',
#  ' 707801',
#  ' 2096034',
#  ' 2441828]',
#  ' [157801',
#  ' 707801',
#  ' 2412799',
#  ' 2651915',
#  ' 2259336',
#  ' 1331693',
#  ' 2441828',
#  ' 1555193]',
#  ' [2096034',
#  ' 836185',
#  ' 2212907]',
#  ' [391959',
#  ' 2441828',
#  ' 391959',
#  ' 641106',
#  ' 2441828',
#  ' 1555193]',
#  ' [2096034',
#  ' 836185',
#  ' 707801',
#  ' 2212907',
#  ' 626770]',
#  ' [391959',
#  ' 2441828',
#  ' 836185',
#  ' 2412799',
#  ' 794261',
#  ' 1555193',
#  ' 2441828]',
#  ' [1672401',
#  ' 2441828',
#  ' 2651915',
#  ' 626770',
#  ' 794261',
#  ' 1555193',
#  ' 2441828]',
#  ' [2259336',
#  ' 977854',
#  ' 2412799',
#  ' 626770',
#  ' 2441828',
#  ' 1555193]',
#  ' [1808918',
#  ' 1672401',
#  ' 836185',
#  ' 2212907',
#  ' 2441828',
#  ' 626770]',
#  ' [2412799',
#  ' 626770',
#  ' 2259336',
#  ' 2212907',
#  ' 2441828]',
#  ' [2412799',
#  ' 1714317',
# ...

# %%
def decode(cypher, priv, phi_n):
    output = list()
    for word in cypher:
        output.append("".join([chr((num**priv) % phi_n) for num in word]))
    return output
